# %%
import pandas as pd
import numpy as np

# %%
from load import train, test
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from load import train, test
#
# File d:\Sentiment Analysis\load.py:1
# ----> 1 from datasets import load_dataset
#       3 dataset = load_dataset("imdb")
#       5 # print(dataset)
#
# ModuleNotFoundError: No module named 'datasets'

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\sapko\AppData\Local\Programs\Python\Python312\python.exe
